# %%
import pandas as pd
import csv
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

# %%
movie_file = Path("../jeff_analysis/final_df.csv")

movie_df = pd.read_csv(movie_file)

movie_df['Director'] = movie_df['Director'].str.replace('Directors:', '')
movie_df.head()
# Out:
#              title     revenue     budget  \
# 0        Inception   825532764  160000000
# 1     Interstellar   701729206  165000000
# 2  The Dark Knight  1004558444  185000000
# 3           Avatar  2923706026  237000000
# 4     The Avengers  1518815515  220000000
#
#                                         genres release_date  \
# 0           Action, Science Fiction, Adventure    7/15/2010
# 1            Adventure, Drama, Science Fiction    11/5/2014
# 2               Drama, Action, Crime, Thriller    7/16/2008
# 3  Action, Adventure, Fantasy, Science Fiction   12/15/2009
# 4           Science Fiction, Action, Adventure    4/25/2012
#
#    Rotten Tomatoes Rating  Metascore      profit           Director  \
# 0                    0.87         74   665532764  Christopher Nolan
# 1                    0.73         74   536729206  Christopher Nolan
# 2                    0.94         84   819558444  Christopher Nolan
# 3                    0.82         83  2686706026      James Cameron
# 4                    0.91         69  1298815515        Joss Whedon
#
#                                               Actors main_genre_movie  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...           Action
# 1  Matthew McConaughey, Anne Hathaway, Jessica Ch...        Adventure
# 2  Christian Bale, Heath Ledger, Aaron Eckhart, M...           Action
# 3  Sam Worthington, Zoe Saldana, Sigourney Weaver...           Action
# 4  Robert Downey Jr., Chris Evans, Scarlett Johan...           Action
#
#        side_genre_movie
# 0    Adventure,  Sci-Fi
# 1        Drama,  Sci-Fi
# 2         Crime,  Drama
# 3   Adventure,  Fantasy
# 4    Adventure,  Sci-Fi

# %%
#Filtering (Cleaning) movie_df

df_unique = movie_df.drop_duplicates(subset='title', keep='first')
filter_criteria = (
    (df_unique['Metascore'].notna()) &
    (df_unique['revenue'].notna()) &
    (df_unique['Metascore'] != 'Rating not found') &
    (df_unique['revenue'] != 'Box Office not found')
    # (df_unique['Total_Gross'] != 'Gross Unknown')
)
clean_movie_df = df_unique[filter_criteria]

# %% [markdown]
# ### The input cell below groups the data by "Single Director" and "Multiple Directors"

# %%
# Create a new column "Director_Type" based on the number of directors
clean_movie_df['Director_Type'] = clean_movie_df['Director'].apply(lambda x: 'Multiple Directors' if ',' in x else 'Single Director')

# Group the DataFrame by the "Director_Type" column
grouped_director_type = clean_movie_df.groupby('Director_Type')

grouped_director_type

# %% [markdown]
# ### The input cell below splits "Multiple Directors" into individual elements

# %%
# Identify rows with multiple directors
multiple_directors_mask = clean_movie_df['Director'].str.contains(',')

# Split multiple directors into individual values and create new rows
multiple_directors_df = clean_movie_df[multiple_directors_mask].copy()
multiple_directors_df['Director'] = multiple_directors_df['Director'].str.split(', ')
multiple_directors_df = multiple_directors_df.explode('Director')

# Combine the original DataFrame with the new rows for multiple directors
updated_movie_df = pd.concat([clean_movie_df[~multiple_directors_mask], multiple_directors_df], ignore_index=True)

# %%
updated_movie_df['Director_Type'].value_counts()
#1790
# Out:
# Director_Type
# Single Director       1391
# Multiple Directors     399
# Name: count, dtype: int64

# %%
director_counts = updated_movie_df['Director_Type'].value_counts()
plt.bar(director_counts.index, director_counts.values)
plt.xlabel('Director Type')
plt.ylabel('Number of Movies')
plt.title('Movies Directed by Single Director vs. Multiple Directors')
plt.show();
single_director_percent = 1391 / 1790 * 100
rounded_single = round(single_director_percent, 2)
multiple_director_percent = 399 / 1790 * 100
rounded_multiple = round(multiple_director_percent, 2)
print(f"Of the ~6000 Top Movies, {rounded_single}% were directed by an individual director, whereas {rounded_multiple}% were directed by multiple directors")
# Out:
# Of the ~6000 Top Movies, 77.71% were directed by an individual director, whereas 22.29% were directed by multiple directors

# %%
# Separate the data for Single Directors and Multiple Directors
single_directors_ratings = updated_movie_df[updated_movie_df['Director_Type'] == 'Single Director']['Metascore']
multiple_directors_ratings = updated_movie_df[updated_movie_df['Director_Type'] == 'Multiple Directors']['Metascore']

# Create a boxplot
plt.figure(figsize=(10, 6))
plt.boxplot([single_directors_ratings, multiple_directors_ratings], labels=['Single Directors', 'Multiple Directors'])
plt.xlabel('Director Type')
plt.ylabel('Metascore')
plt.title('Boxplot of Movie Ratings by Director Type')
plt.show()
# Not sure if this is something noteable, but I'll save it just in case. Mean rating (red line) for Single Directors is 6.75, 
# while the mean rating for multiple directors is 6.84.
single_mean_score = round(single_directors_ratings.mean(),2)
multiple_mean_score = round(multiple_directors_ratings.mean(),2)
print(f"The mean score for movies directed by an individual was {single_mean_score}, whereas the mean score for movies directed by multiple directors was {multiple_mean_score}")
# Out:
# The mean score for movies directed by an individual was 60.54, whereas the mean score for movies directed by multiple directors was 68.79

# %%
# cleaned_boxoffice = clean_movie_df.loc[(clean_movie_df['revenue'] != "Metascore not found") & (clean_movie_df['Metascore'].notna())]
# cleaned_boxoffice['Metascore'] = cleaned_boxoffice['Metascore'].str.replace('[\$,]', '', regex=True).astype(int)

box_and_directortype = updated_movie_df[['revenue', 'Director_Type']]

single_directors_box = box_and_directortype[box_and_directortype['Director_Type'] == 'Single Director']['revenue']
multiple_directors_box = box_and_directortype[box_and_directortype['Director_Type'] == 'Multiple Directors']['revenue']
plt.boxplot([single_directors_box, multiple_directors_box], labels=['Single Directors', 'Multiple Directors'])
plt.xlabel('Director Type')
plt.ylabel('Revenue in 100 Millions')
plt.show();

# %%
# Top Directors dataframe
clean_movie_df['Director']

# Split directors in cells containing multiple directors into separate rows
directors_df = clean_movie_df['Director'].str.split(',', expand=True).stack().reset_index(level=1, drop=True).rename('Director')

# Count the occurrences of each director
director_counts = directors_df.value_counts()

# Sort the directors based on the number of movies they have made
most_movies_directors = director_counts.head()


# Display the directors who made the most movies
most_movies_directors_df = most_movies_directors.reset_index()
most_movies_directors_df.columns = ['Director', 'Total Movies Directed']
most_movies_directors_df
# Out:
#            Director  Total Movies Directed
# 0  Steven Spielberg                     22
# 1    Clint Eastwood                     15
# 2        Tim Burton                     14
# 3      Ridley Scott                     13
# 4   Robert Zemeckis                     12

# %%
# Plotting the directors who made the most movies as a bar chart
plt.figure(figsize=(10, 6))
most_movies_directors.plot(kind='bar', color='skyblue')
plt.title('Directors Who Made the Most Movies')
plt.xlabel('Director')
plt.ylabel('Number of Movies')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the bar chart
plt.show();

# %%
top_directors = ['Steven Spielberg', 'Clint Eastwood', 'Tim Burton', 'Ridley Scott', 'Robert Zemeckis']

top_directors_df = clean_movie_df[clean_movie_df['Director'].str.contains('|'.join(top_directors))].sort_values(by='Director')
top_directors_df_clean = top_directors_df.assign(Director=top_directors_df['Director'].str.split(', ')).explode('Director')
top_directors_df_clean['Director'].tolist()
# Out:
# ['Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Don Siegel',
#  'Clint Eastwood',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Robert Zemeckis',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Mike Johnson']

# %%
# List of the top 5 directors
top_directors = ['Steven Spielberg', 'Clint Eastwood', 'Tim Burton', 'Ridley Scott', 'Robert Zemeckis']

# Create a new DataFrame with rows that match the top directors
top_directors_df = clean_movie_df[clean_movie_df['Director'].str.contains('|'.join(top_directors))].sort_values(by='Director')

# Display the new DataFrame
top_directors_df_clean = top_directors_df.assign(Director=top_directors_df['Director'].str.split(', ')).explode('Director')

# List of directors to remove
directors_to_remove = ['Don Siegel', 'Mike Johnson']

# Filter out the directors to remove from the DataFrame
top_directors_filtered = top_directors_df_clean[~top_directors_df['Director'].isin(directors_to_remove)]

# Create a vertical box plot for the average revenue data of the top directors
plt.figure(figsize=(12, 8))
plt.boxplot([top_directors_filtered[top_directors_filtered['Director'] == director]['revenue'] for director in top_directors],
            labels=top_directors)
plt.xticks(rotation=45)
plt.xlabel('Top Directors')
plt.ylabel('Average Revenue')
plt.title('Vertical Box Plot of Average Revenue for Top Directors')
plt.show()

for index, row in top_directors_filtered.iterrows():
    average_revenue_style = '{:,.2f}'.format(row['revenue'])
    print(f"The average box office for director {row['Director']} is ${average_revenue_style}")
# Out:
# C:\Users\jvvil\AppData\Local\Temp\ipykernel_20528\647149655.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   top_directors_filtered = top_directors_df_clean[~top_directors_df['Director'].isin(directors_to_remove)]
# The average box office for director Clint Eastwood is $31,794,718.00
# The average box office for director Clint Eastwood is $240,797,623.00
# The average box office for director Clint Eastwood is $174,804,407.00
# The average box office for director Clint Eastwood is $216,763,646.00
# The average box office for director Clint Eastwood is $159,157,447.00
# The average box office for director Clint Eastwood is $113,398,237.00
# The average box office for director Clint Eastwood is $150,000,000.00
# The average box office for director Clint Eastwood is $122,426,792.00
# The average box office for director Clint Eastwood is $542,307,423.00
# The average box office for director Clint Eastwood is $269,958,228.00
# The average box office for director Clint Eastwood is $156,822,020.00
# The average box office for director Clint Eastwood is $50,068,310.00
# The average box office for director Clint Eastwood is $68,673,228.00
# The average box office for director Clint Eastwood is $65,900,249.00
# The average box office for director Clint Eastwood is $128,884,132.00
# The average box office for director Don Siegel is $35,976,000.00
# The average box office for director Clint Eastwood is $35,976,000.00
# The average box office for director Ridley Scott is $630,600,000.00
# The average box office for director Ridley Scott is $172,989,651.00
# The average box office for director Ridley Scott is $266,465,037.00
# The average box office for director Ridley Scott is $351,692,268.00
# The average box office for director Ridley Scott is $321,669,741.00
# The average box office for director Ridley Scott is $268,031,828.00
# The average box office for director Ridley Scott is $41,722,424.00
# The average box office for director Ridley Scott is $465,361,176.00
# The average box office for director Ridley Scott is $134,212,055.00
# The average box office for director Ridley Scott is $403,354,469.00
# The average box office for director Ridley Scott is $218,122,627.00
# The average box office for director Ridley Scott is $45,361,000.00
# The average box office for director Ridley Scott is $30,500,000.00
# The average box office for director Robert Zemeckis is $119,520,023.00
# The average box office for director Robert Zemeckis is $171,120,329.00
# The average box office for director Robert Zemeckis is $329,803,958.00
# The average box office for director Robert Zemeckis is $161,772,375.00
# The average box office for director Robert Zemeckis is $195,735,876.00
# The average box office for director Robert Zemeckis is $325,286,646.00
# The average box office for director Robert Zemeckis is $677,387,716.00
# The average box office for director Robert Zemeckis is $244,527,583.00
# The average box office for director Robert Zemeckis is $381,109,762.00
# The average box office for director Robert Zemeckis is $332,000,000.00
# The average box office for director Robert Zemeckis is $429,632,142.00
# The average box office for director Robert Zemeckis is $310,634,054.00
# The average box office for director Steven Spielberg is $333,000,000.00
# The average box office for director Steven Spielberg is $130,982,129.00
# The average box office for director Steven Spielberg is $389,925,971.00
# The average box office for director Steven Spielberg is $352,114,312.00
# The average box office for director Steven Spielberg is $306,889,114.00
# The average box office for director Steven Spielberg is $607,274,134.00
# The average box office for director Steven Spielberg is $321,365,567.00
# The average box office for director Steven Spielberg is $474,171,806.00
# The average box office for director Steven Spielberg is $165,478,348.00
# The average box office for director Steven Spielberg is $481,840,909.00
# The average box office for director Steven Spielberg is $358,372,926.00
# The average box office for director Steven Spielberg is $618,638,999.00
# The average box office for director Steven Spielberg is $179,769,467.00
# The average box office for director Steven Spielberg is $603,873,119.00
# The average box office for director Steven Spielberg is $786,636,033.00
# The average box office for director Steven Spielberg is $300,855,000.00
# The average box office for director Steven Spielberg is $219,417,255.00
# The average box office for director Steven Spielberg is $920,100,000.00
# The average box office for director Steven Spielberg is $373,993,951.00
# The average box office for director Steven Spielberg is $235,926,552.00
# The average box office for director Steven Spielberg is $275,293,450.00
# The average box office for director Steven Spielberg is $177,584,879.00
# The average box office for director Tim Burton is $245,527,149.00
# The average box office for director Tim Burton is $474,968,763.00
# The average box office for director Tim Burton is $53,000,000.00
# The average box office for director Tim Burton is $123,218,424.00
# The average box office for director Tim Burton is $28,883,511.00
# The average box office for director Tim Burton is $362,211,740.00
# The average box office for director Tim Burton is $152,000,000.00
# The average box office for director Tim Burton is $206,071,502.00
# The average box office for director Tim Burton is $296,482,446.00
# The average box office for director Tim Burton is $101,371,017.00
# The average box office for director Tim Burton is $411,348,924.00
# The average box office for director Tim Burton is $81,493,846.00
# The average box office for director Tim Burton is $280,000,000.00
# The average box office for director Tim Burton is $118,133,252.00
# The average box office for director Mike Johnson is $118,133,252.00

# %%
top_directors_filtered['Director'].tolist()
# Out:
# ['Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Clint Eastwood',
#  'Don Siegel',
#  'Clint Eastwood',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Ridley Scott',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Steven Spielberg',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Tim Burton',
#  'Mike Johnson']

# %%
#Transforming Metascore from Object into Float to get summary stats
clean_movie_df['Metascore'].astype(float).describe()
# Out:
# count    758.000000
# mean      60.608179
# std       13.480679
# min       14.000000
# 25%       51.000000
# 50%       60.000000
# 75%       70.000000
# max       98.000000
# Name: Metascore, dtype: float64

# %%
# Transforming Metascore in the Top 5 Directors into float to get summary stats
top_directors_df_clean_split['Metascore'] = top_directors_df_clean_split['Metascore'].astype(float)
top_director_metascore = top_directors_df_clean_split.groupby('Director')['Metascore'].mean()
top_director_metascore
# Out:
# Director
# Antoine Fuqua       52.250000
# Michael Bay         47.875000
# Richard Donner      58.875000
# Steven Spielberg    69.545455
# Tony Scott          57.600000
# Name: Metascore, dtype: float64

# %%
# Data for mean Metascore per director to be used for Bar Graph
director_names = ['Antoine Fuqua', 'Michael Bay', 'Richard Donner', 'Steven Spielberg', 'Tony Scott']
mean_metascores = [52.25, 47.875, 58.875, 69.545455, 57.6]

plt.figure(figsize=(12, 6))
bars = plt.bar(director_names, mean_metascores, color='skyblue')
plt.xlabel('Director')
plt.ylabel('Mean Metascore')
plt.title('Mean Metascore per Director')
plt.xticks(rotation=45)

# Showing a horizontal line of the mean metascore of all movies in the clean_movie_df
plt.axhline(y=60.6, color='b', linestyle='--', label='Overall Mean Metascore = 60.61')
plt.legend()

# Labelling each Bar with its corresponding value
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 1), va='bottom', ha='center', fontsize=12)

plt.show();
